# %% [markdown]
# DATA GENERATION FOR SUPERMARKET TRANSACTIONS
# Contributor: Abdiqalaq

# %%
#import necessary libraries
import random
import pandas as pd

# Step 1: Create a pool of at least 30 supermarket items
 
item_pool = [
    "Bread", "Milk", "Eggs", "Butter", "Cheese", "Apples", "Bananas", "Chicken",
    "Rice", "Pasta", "Tomatoes", "Onions", "Cereal", "Yogurt", "Juice", "Beef",
    "Fish", "Salt", "Sugar", "Tea", "Coffee", "Chips", "Soda", "Water",
    "Flour", "Oil", "Spices", "Ice Cream", "Chocolate", "Lettuce"
]


# Step 2: Generate at least 3000 transactions
# Each transaction will have 2–7 randomly selected items

num_transactions = 3000   # Requirement: minimum 3000
transactions = []

for _ in range(num_transactions):
    transaction_size = random.randint(2, 7)           # number of items in one transaction
    transaction = random.sample(item_pool, transaction_size)  
    transactions.append(transaction)

# ---------------------------------------------------------------
# Step 3: Save as CSV for later use in Apriori
# ---------------------------------------------------------------
transactions = pd.DataFrame({"Transaction": transactions})
#transactions.to_csv("transactions.csv", index=False)

print("Generated 3000 supermarket transactions successfully!")
# Out:
# Generated 3000 supermarket transactions successfully!

# %% [markdown]
# One hot encoder ~ Bradley Ochola 346

# %%
from mlxtend.preprocessing import TransactionEncoder

te=TransactionEncoder()
to_data=te.fit_transform(transactions)
transactions=pd.DataFrame(to_data,columns=te.columns_)

print("\nSample of the one-hot encoded transactions:", transactions.head())
# Out:
# Sample of the one-hot encoded transactions:    Apples  Bananas   Beef  Bread  Butter  Cereal  Cheese  Chicken  Chips  \
# 0    True    False  False  False   False   False   False    False  False
# 1   False     True  False   True   False   False   False    False   True
# 2   False    False  False  False   False   False   False    False  False
# 3    True    False  False  False   False   False   False    False  False
# 4    True     True  False   True   False   False    True    False  False
#
#    Chocolate  ...  Pasta   Rice   Salt   Soda  Spices  Sugar    Tea  Tomatoes  \
# 0       True  ...  False  False  False  False   False  False  False     False
# 1      False  ...  False  False  False  False   False  False  False     False
# 2      False  ...   True  False  False  False    True  False  False      True
# 3      False  ...  False  False  False  False    True   True  False     False
# 4      False  ...  False  False  False  False    True  False  False     False
#
#    Water  Yogurt
# 0   True   False
# 1  False   False
# 2  False   False
# 3  False   False
# 4  False    True
#
# [5 rows x 30 columns]
